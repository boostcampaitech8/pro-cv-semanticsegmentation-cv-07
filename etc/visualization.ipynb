# %% [markdown]
# Cell 1. Import

# %%
from etc.visualization import analyze_spike
from etc.report_visualization import generate_spike_report
from src.data.train_data import XRayDataset

# %% [markdown]
# Cell 2. visulization

# %%
val_dataset = XRayDataset(fold=0, is_train=False)

analyze_spike(
    ckpt_prev=".../epoch10.pt",
    ckpt_spike=".../spike_up_e12_d0.6231.pt",
    ckpt_next=".../epoch14.pt",
    val_dataset=val_dataset,
    topk=3
)

# %% [markdown]
# Cell 3. report_visulization

# %%
val_dataset = XRayDataset(fold=0, is_train=False)

generate_spike_report(
    ckpt_prev=".../epoch10.pt",
    ckpt_spike=".../spike_up_e12_d0.6231.pt",
    ckpt_next=".../epoch14.pt",
    val_dataset=val_dataset,
    out_root="./report_figures",
    topk=3
)
